# %%
import language_tool_python
# Out:
# Downloading LanguageTool 5.7:   0%|                                                         | 0.00/225M [00:00<?, ?B/s]
#
# Downloading LanguageTool 5.7:   0%|▏                                                | 705k/225M [00:00<00:32, 6.92MB/s]
#
# Downloading LanguageTool 5.7:   1%|▌                                               | 2.44M/225M [00:00<00:20, 10.9MB/s]
#
# Downloading LanguageTool 5.7:   2%|▋                                               | 3.49M/225M [00:00<00:24, 9.10MB/s]
#
# Downloading LanguageTool 5.7:   2%|█▏                                              | 5.52M/225M [00:00<00:17, 12.7MB/s]
#
# Downloading LanguageTool 5.7:   3%|█▌                                              | 7.39M/225M [00:00<00:14, 14.6MB/s]
#
# Downloading LanguageTool 5.7:   4%|█▉                                              | 8.91M/225M [00:00<00:15, 14.1MB/s]
#
# Downloading LanguageTool 5.7:   5%|██▏                                             | 10.5M/225M [00:00<00:14, 14.3MB/s]
#
# Downloading LanguageTool 5.7:   6%|██▋                                             | 12.8M/225M [00:00<00:12, 16.5MB/s]
#
# Downloading LanguageTool 5.7:   7%|███▏                                            | 14.8M/225M [00:01<00:12, 17.3MB/s]
#
# Downloading LanguageTool 5.7:   7%|███▌                                            | 16.7M/225M [00:01<00:11, 17.8MB/s]
#
# Downloading LanguageTool 5.7:   8%|████                                            | 18.9M/225M [00:01<00:10, 19.2MB/s]
#
# Downloading LanguageTool 5.7:   9%|████▍                                           | 20.9M/225M [00:01<00:11, 18.2MB/s]
#
# Downloading LanguageTool 5.7:  10%|████▉                                           | 23.1M/225M [00:01<00:10, 19.2MB/s]
#
# Downloading LanguageTool 5.7:  11%|█████▍                                          | 25.3M/225M [00:01<00:10, 19.9MB/s]
#
# Downloading LanguageTool 5.7:  12%|█████▊                                          | 27.3M/225M [00:01<00:10, 18.4MB/s]
#
# Downloading LanguageTool 5.7:  13%|██████▏                                         | 29.2M/225M [00:01<00:10, 18.4MB/s]
#
# Downloading LanguageTool 5.7:  14%|██████▋                                         | 31.3M/225M [00:01<00:10, 19.0MB/s]
#
# Downloading LanguageTool 5.7:  15%|███████                                         | 33.2M/225M [00:01<00:10, 18.9MB/s]
#
# Downloading LanguageTool 5.7:  16%|███████▍                                        | 35.1M/225M [00:02<00:10, 18.3MB/s]
#
# Downloading LanguageTool 5.7:  16%|███████▉                                        | 36.9M/225M [00:02<00:10, 18.2MB/s]
#
# Downloading LanguageTool 5.7:  17%|████████▎                                       | 38.9M/225M [00:02<00:10, 18.6MB/s]
#
# Downloading LanguageTool 5.7:  18%|████████▋                                       | 40.8M/225M [00:02<00:10, 17.1MB/s]
#
# Downloading LanguageTool 5.7:  19%|█████████                                       | 42.5M/225M [00:02<00:10, 16.9MB/s]
#
# Downloading LanguageTool 5.7:  20%|█████████▍                                      | 44.5M/225M [00:02<00:10, 17.5MB/s]
#
# Downloading LanguageTool 5.7:  21%|█████████▉                                      | 46.4M/225M [00:02<00:09, 18.0MB/s]
#
# Downloading LanguageTool 5.7:  22%|██████████▎                                     | 48.4M/225M [00:02<00:09, 18.5MB/s]
#
# Downloading LanguageTool 5.7:  22%|██████████▊                                     | 50.4M/225M [00:02<00:09, 18.0MB/s]
#
# Downloading LanguageTool 5.7:  23%|███████████▏                                    | 52.2M/225M [00:03<00:09, 17.3MB/s]
#
# Downloading LanguageTool 5.7:  24%|███████████▌                                    | 54.4M/225M [00:03<00:09, 18.3MB/s]
#
# Downloading LanguageTool 5.7:  25%|████████████                                    | 56.5M/225M [00:03<00:08, 19.1MB/s]
#
# Downloading LanguageTool 5.7:  26%|████████████▍                                   | 58.4M/225M [00:03<00:08, 18.8MB/s]
#
# Downloading LanguageTool 5.7:  27%|████████████▉                                   | 60.5M/225M [00:03<00:08, 19.3MB/s]
#
# Downloading LanguageTool 5.7:  28%|█████████████▎                                  | 62.4M/225M [00:03<00:08, 19.4MB/s]
#
# Downloading LanguageTool 5.7:  29%|█████████████▊                                  | 64.5M/225M [00:03<00:08, 19.7MB/s]
#
# Downloading LanguageTool 5.7:  30%|██████████████▏                                 | 66.5M/225M [00:03<00:08, 18.9MB/s]
#
# Downloading LanguageTool 5.7:  30%|██████████████▌                                 | 68.5M/225M [00:03<00:08, 19.0MB/s]
#
# Downloading LanguageTool 5.7:  32%|███████████████▏                                | 70.9M/225M [00:03<00:07, 20.6MB/s]
#
# Downloading LanguageTool 5.7:  33%|███████████████▌                                | 73.1M/225M [00:04<00:07, 20.8MB/s]
#
# Downloading LanguageTool 5.7:  34%|████████████████                                | 75.4M/225M [00:04<00:07, 21.1MB/s]
#
# Downloading LanguageTool 5.7:  34%|████████████████▌                               | 77.5M/225M [00:04<00:07, 21.0MB/s]
#
# Downloading LanguageTool 5.7:  35%|█████████████████                               | 79.8M/225M [00:04<00:06, 21.6MB/s]
#
# Downloading LanguageTool 5.7:  36%|█████████████████▍                              | 81.9M/225M [00:04<00:06, 20.9MB/s]
#
# Downloading LanguageTool 5.7:  37%|█████████████████▉                              | 84.0M/225M [00:04<00:07, 20.0MB/s]
#
# Downloading LanguageTool 5.7:  38%|██████████████████▎                             | 86.0M/225M [00:04<00:07, 18.7MB/s]
#
# Downloading LanguageTool 5.7:  39%|██████████████████▊                             | 88.4M/225M [00:04<00:06, 19.8MB/s]
#
# Downloading LanguageTool 5.7:  40%|███████████████████▎                            | 90.4M/225M [00:04<00:06, 20.0MB/s]
#
# Downloading LanguageTool 5.7:  41%|███████████████████▊                            | 92.8M/225M [00:05<00:06, 21.0MB/s]
#
# Downloading LanguageTool 5.7:  42%|████████████████████▎                           | 95.0M/225M [00:05<00:06, 21.2MB/s]
#
# Downloading LanguageTool 5.7:  43%|████████████████████▊                           | 97.5M/225M [00:05<00:05, 22.1MB/s]
#
# Downloading LanguageTool 5.7:  44%|█████████████████████▎                          | 99.7M/225M [00:05<00:05, 21.8MB/s]
#
# Downloading LanguageTool 5.7:  45%|██████████████████████▏                          | 102M/225M [00:05<00:05, 21.2MB/s]
#
# Downloading LanguageTool 5.7:  46%|██████████████████████▋                          | 104M/225M [00:05<00:05, 21.1MB/s]
#
# Downloading LanguageTool 5.7:  47%|███████████████████████▏                         | 106M/225M [00:05<00:05, 20.3MB/s]
#
# Downloading LanguageTool 5.7:  48%|███████████████████████▌                         | 108M/225M [00:05<00:05, 20.3MB/s]
#
# Downloading LanguageTool 5.7:  49%|████████████████████████                         | 110M/225M [00:05<00:05, 19.2MB/s]
#
# Downloading LanguageTool 5.7:  50%|████████████████████████▍                        | 112M/225M [00:06<00:05, 19.3MB/s]
#
# Downloading LanguageTool 5.7:  51%|████████████████████████▉                        | 115M/225M [00:06<00:05, 20.1MB/s]
#
# Downloading LanguageTool 5.7:  52%|█████████████████████████▍                       | 117M/225M [00:06<00:05, 20.8MB/s]
#
# Downloading LanguageTool 5.7:  53%|█████████████████████████▉                       | 119M/225M [00:06<00:04, 21.4MB/s]
#
# Downloading LanguageTool 5.7:  54%|██████████████████████████▍                      | 121M/225M [00:06<00:04, 21.6MB/s]
#
# Downloading LanguageTool 5.7:  55%|██████████████████████████▉                      | 124M/225M [00:06<00:04, 21.6MB/s]
#
# Downloading LanguageTool 5.7:  56%|███████████████████████████▍                     | 126M/225M [00:06<00:04, 20.8MB/s]
#
# Downloading LanguageTool 5.7:  57%|███████████████████████████▉                     | 128M/225M [00:06<00:04, 19.8MB/s]
#
# Downloading LanguageTool 5.7:  58%|████████████████████████████▎                    | 130M/225M [00:06<00:05, 16.7MB/s]
#
# Downloading LanguageTool 5.7:  59%|████████████████████████████▋                    | 132M/225M [00:07<00:05, 17.2MB/s]
#
# Downloading LanguageTool 5.7:  60%|█████████████████████████████▏                   | 134M/225M [00:07<00:05, 18.0MB/s]
#
# Downloading LanguageTool 5.7:  60%|█████████████████████████████▌                   | 136M/225M [00:07<00:04, 18.4MB/s]
#
# Downloading LanguageTool 5.7:  61%|██████████████████████████████                   | 138M/225M [00:07<00:04, 19.2MB/s]
#
# Downloading LanguageTool 5.7:  62%|██████████████████████████████▌                  | 140M/225M [00:07<00:04, 19.8MB/s]
#
# Downloading LanguageTool 5.7:  63%|██████████████████████████████▉                  | 142M/225M [00:07<00:04, 18.2MB/s]
#
# Downloading LanguageTool 5.7:  64%|███████████████████████████████▍                 | 144M/225M [00:07<00:04, 18.3MB/s]
#
# Downloading LanguageTool 5.7:  65%|███████████████████████████████▊                 | 146M/225M [00:07<00:04, 17.4MB/s]
#
# Downloading LanguageTool 5.7:  66%|████████████████████████████████▎                | 148M/225M [00:07<00:04, 18.1MB/s]
#
# Downloading LanguageTool 5.7:  67%|████████████████████████████████▋                | 150M/225M [00:08<00:04, 17.4MB/s]
#
# Downloading LanguageTool 5.7:  68%|█████████████████████████████████                | 152M/225M [00:08<00:03, 18.4MB/s]
#
# Downloading LanguageTool 5.7:  69%|█████████████████████████████████▌               | 154M/225M [00:08<00:03, 18.4MB/s]
#
# Downloading LanguageTool 5.7:  69%|██████████████████████████████████               | 156M/225M [00:08<00:03, 19.4MB/s]
#
# Downloading LanguageTool 5.7:  70%|██████████████████████████████████▌              | 158M/225M [00:08<00:03, 20.0MB/s]
#
# Downloading LanguageTool 5.7:  71%|██████████████████████████████████▉              | 160M/225M [00:08<00:03, 20.3MB/s]
#
# Downloading LanguageTool 5.7:  72%|███████████████████████████████████▍             | 162M/225M [00:08<00:03, 20.2MB/s]
#
# Downloading LanguageTool 5.7:  73%|███████████████████████████████████▉             | 165M/225M [00:08<00:02, 20.6MB/s]
#
# Downloading LanguageTool 5.7:  74%|████████████████████████████████████▍            | 167M/225M [00:08<00:02, 21.2MB/s]
#
# Downloading LanguageTool 5.7:  75%|████████████████████████████████████▊            | 169M/225M [00:08<00:02, 20.9MB/s]
#
# Downloading LanguageTool 5.7:  76%|█████████████████████████████████████▎           | 171M/225M [00:09<00:02, 20.5MB/s]
#
# Downloading LanguageTool 5.7:  77%|█████████████████████████████████████▊           | 173M/225M [00:09<00:02, 20.5MB/s]
#
# Downloading LanguageTool 5.7:  78%|██████████████████████████████████████▏          | 175M/225M [00:09<00:02, 20.4MB/s]
#
# Downloading LanguageTool 5.7:  79%|██████████████████████████████████████▋          | 177M/225M [00:09<00:02, 20.1MB/s]
#
# Downloading LanguageTool 5.7:  80%|███████████████████████████████████████          | 179M/225M [00:09<00:02, 20.0MB/s]
#
# Downloading LanguageTool 5.7:  81%|███████████████████████████████████████▌         | 181M/225M [00:09<00:02, 19.4MB/s]
#
# Downloading LanguageTool 5.7:  82%|███████████████████████████████████████▉         | 183M/225M [00:09<00:02, 19.5MB/s]
#
# Downloading LanguageTool 5.7:  83%|████████████████████████████████████████▍        | 186M/225M [00:09<00:02, 19.6MB/s]
#
# Downloading LanguageTool 5.7:  83%|████████████████████████████████████████▉        | 188M/225M [00:09<00:01, 20.2MB/s]
#
# Downloading LanguageTool 5.7:  84%|█████████████████████████████████████████▍       | 190M/225M [00:09<00:01, 20.6MB/s]
#
# Downloading LanguageTool 5.7:  85%|█████████████████████████████████████████▊       | 192M/225M [00:10<00:01, 20.6MB/s]
#
# Downloading LanguageTool 5.7:  86%|██████████████████████████████████████████▎      | 194M/225M [00:10<00:01, 20.7MB/s]
#
# Downloading LanguageTool 5.7:  87%|██████████████████████████████████████████▊      | 196M/225M [00:10<00:01, 20.9MB/s]
#
# Downloading LanguageTool 5.7:  88%|███████████████████████████████████████████▏     | 198M/225M [00:10<00:01, 20.3MB/s]
#
# Downloading LanguageTool 5.7:  89%|███████████████████████████████████████████▋     | 200M/225M [00:10<00:01, 19.4MB/s]
#
# Downloading LanguageTool 5.7:  90%|████████████████████████████████████████████     | 202M/225M [00:10<00:01, 19.3MB/s]
#
# Downloading LanguageTool 5.7:  91%|████████████████████████████████████████████▌    | 204M/225M [00:10<00:01, 18.7MB/s]
#
# Downloading LanguageTool 5.7:  92%|████████████████████████████████████████████▉    | 206M/225M [00:10<00:00, 19.4MB/s]
#
# Downloading LanguageTool 5.7:  93%|█████████████████████████████████████████████▍   | 209M/225M [00:10<00:00, 20.0MB/s]
#
# Downloading LanguageTool 5.7:  94%|█████████████████████████████████████████████▉   | 211M/225M [00:11<00:00, 19.2MB/s]
#
# Downloading LanguageTool 5.7:  95%|██████████████████████████████████████████████▎  | 213M/225M [00:11<00:00, 18.4MB/s]
#
# Downloading LanguageTool 5.7:  95%|██████████████████████████████████████████████▋  | 214M/225M [00:11<00:00, 18.3MB/s]
#
# Downloading LanguageTool 5.7:  96%|███████████████████████████████████████████████▏ | 216M/225M [00:11<00:00, 18.0MB/s]
#
# Downloading LanguageTool 5.7:  97%|███████████████████████████████████████████████▌ | 218M/225M [00:11<00:00, 17.7MB/s]
#
# Downloading LanguageTool 5.7:  98%|███████████████████████████████████████████████▉ | 220M/225M [00:11<00:00, 17.4MB/s]
#
# Downloading LanguageTool 5.7:  99%|████████████████████████████████████████████████▎| 222M/225M [00:11<00:00, 17.5MB/s]
#
# Downloading LanguageTool 5.7: 100%|█████████████████████████████████████████████████| 225M/225M [00:11<00:00, 18.9MB/s]
# Unzipping C:\Users\ADITYA~1\AppData\Local\Temp\tmpeaf7xs7m.zip to C:\Users\Adityavardhan Jain\.cache\language_tool_python.
# Downloaded https://www.languagetool.org/download/LanguageTool-5.7.zip to C:\Users\Adityavardhan Jain\.cache\language_tool_python.
# Error: PERS_PRONOUN_AGREEMENT
# Message: Did you mean “am” or “will be”?
# Suggestions: ['am', 'will be']
# -----------
# Error: NON3PRS_VERB
# Message: The pronoun ‘I’ must be used with a non-third-person form of a verb.
# Suggestions: ['have']
# -----------

# %%
# def grammar_check(text):
#     # Create a LanguageTool instance
#     tool = language_tool_python.LanguageTool('en-US')
    
#     # Check the text for grammar errors
#     matches = tool.check(text)
    
#     # Print the matches (grammar errors)
#     for match in matches:
#         print("Error:", match.ruleId)
#         print("Message:", match.message)
#         print("Suggestions:", match.replacements)
#         print("-----------")

# # Input text to be checked for grammar errors
# input_text = "I is a student and I has many books."

# # Perform grammar check
# grammar_check(input_text)
# Out:
# Error: PERS_PRONOUN_AGREEMENT
# Message: Did you mean “am” or “will be”?
# Suggestions: ['am', 'will be']
# -----------
# Error: NON3PRS_VERB
# Message: The pronoun ‘I’ must be used with a non-third-person form of a verb.
# Suggestions: ['have']
# -----------

# %%
def grammar_check(text):

    tool = language_tool_python.LanguageTool('en-US')

    matches = tool.check(text)

    for match in matches:
        print("Error:", match.ruleId)
        print("Message:", match.message)
        print("Suggestions:", match.replacements)
        print("-----------")

input_text = input("Enter the text to be checked for grammar errors: ")
grammar_check(input_text)
# Out:
# Enter the text to be checked for grammar errors:  he am was went to new york
# Error: UPPERCASE_SENTENCE_START
# Message: This sentence does not start with an uppercase letter.
# Suggestions: ['He']
# -----------
# Error: PERS_PRONOUN_AGREEMENT
# Message: Use third-person verb with ‘he’.
# Suggestions: ['is', 'was']
# -----------
# Error: EN_SPECIFIC_CASE
# Message: If the term is a proper noun, use initial capitals.
# Suggestions: ['New York']
# -----------
